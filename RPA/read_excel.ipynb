# %%
import pandas as pd

# %%
df = pd.read_excel("test.xlsx")

# %%
test = df.iloc[4:,1:25]
test = test.rename(columns=test.iloc[0])
test = test.set_index("No")
test = test.loc[1:]
test
# Out:
#           ITRNo  요청서                         제목   분류  접수년도  접수월 접수일\nWW  완료년도  \
# No
# 1.0  201911-001    Y           재작업지시 설비변경 기능 추가  MES  2019   11      47  2019
# 2.0  201911-002    Y        공정별 반제품 조회 화면 수정 요청  MES  2019   11      48  2019
# 3.0  201911-003    Y  재측정 제품의 검사데이타 WMS 업데이트 요청  MES  2019   11      48  2019
# 4.0  201911-004    Y                 검사데이타 전송 건  MES  2019   11      48  2020
# 5.0  201911-005    Y           검사데이타 외관항목 기입 추가  MES  2019   11      48  2019
# ..          ...  ...                        ...  ...   ...  ...     ...   ...
# NaN  202208-359  NaN                        NaN  NaN   NaN  NaN     NaN   NaN
# NaN  202208-360  NaN                        NaN  NaN   NaN  NaN     NaN   NaN
# NaN  202208-361  NaN                        NaN  NaN   NaN  NaN     NaN   NaN
# NaN  202208-362  NaN                        NaN  NaN   NaN  NaN     NaN   NaN
# NaN  202208-363  NaN                        NaN  NaN   NaN  NaN     NaN   NaN
#
# ...
